# %% [markdown]
# ### 알바몬 크롤러
# ### 20184645 김영찬

# %%
# !pip install selenium
# !pip install bs4
import time
import urllib
from selenium import webdriver
from bs4 import BeautifulSoup
# Out:
# Requirement already satisfied: selenium in c:\users\rmawk\appdata\local\programs\python\python39\lib\site-packages (3.141.0)
# Requirement already satisfied: urllib3 in c:\users\rmawk\appdata\local\programs\python\python39\lib\site-packages (from selenium) (1.26.6)
# Requirement already satisfied: bs4 in c:\users\rmawk\appdata\local\programs\python\python39\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\rmawk\appdata\local\programs\python\python39\lib\site-packages (from bs4) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\rmawk\appdata\local\programs\python\python39\lib\site-packages (from beautifulsoup4->bs4) (2.2.1)

# %%
# 먼저, 크롬을 켜 알바몬 사이트에 접속
browser = webdriver.Chrome("./chromedriver.exe")
browser.get("https://www.albamon.com/main")

# %%
main=browser.find_element_by_id("btn_MType")
main.click()

browser.find_element_by_link_text("경기").click()
browser.find_element_by_link_text("수원시 장안구").click()
time.sleep(1)
browser.find_element_by_id("dev_area_dong_code_B190").click()
s_location=browser.find_element_by_class_name("sch")
s_location.click()
time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8976/3966729101.py in <module>
# ----> 1 main=browser.find_element_by_id("btn_MType")
#       2 main.click()
#       3
#       4 browser.find_element_by_link_text("경기").click()
#       5 browser.find_element_by_link_text("수원시 장안구").click()
#
# c:\users\rmawk\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_id(self, id_)
#     358             element = driver.find_element_by_id('foo')
#     359         """
# --> 360         return self.find_element(by=By.ID, value=id_)
#     361
#     362     def find_elements_by_id(self, id_):
#
# c:\users\rmawk\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# c:\users\rmawk\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# c:\users\rmawk\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="btn_MType"]"}
#   (Session info: chrome=93.0.4577.82)

# %%
base_url = urllib.request.urlopen(browser.current_url).read()
soup = BeautifulSoup(base_url,"html.parser")

ths = []

wrap = soup.find('div',{"class":"gListWrap"})
table = wrap.find('table')
t_head = table.find('thead').find_all('th')
t_body = table.find('tbody')

for th in t_head:
    ths.append(th.get_text())

print("{0}\t\t{1}\t\t{2}\t\t{3}\t\t{4}".format(ths[0],ths[1],ths[2],ths[3],ths[4]))

for tr in t_body.find_all('tr'):
    area = tr.find('td',{'class':'area'}).find('div')
    area.span.decompose()
    subject_name = tr.find('td',{'class':'subject'}).find('p',{'class':'cName'}).text
    subject_ctit = tr.find('td',{'class':'subject'}).find('p',{'class':'cTit'}).text
    pay_money = tr.find('td',{'class':'pay'}).find('p',{'class':'money'}).find("img")["alt"]
    pay_won = tr.find('td',{'class':'pay'}).find('p',{'class':'won'}).text
    print(area.text + subject_name + "( {} )".format(subject_ctit) + "\t" +pay_money +" : "+ pay_won)
    print("--------------------------------------------------------------------------------------------------")
# Out:
# 지역		기업명/모집제목		급여		근무시간		등록일
#
# 수원시 장안구
#
#
# 다이소
# (  [직영사원/ 급여 GOOD] 다이소 용인물류 주&야간 남여 )	월급 : 3,000,000원
# --------------------------------------------------------------------------------------------------
#
# 수원시 장안구
#
#
# 다이소
# (  [일급15만/다이소]#단기,장기,친구동반,근무일 선택  )	일급 : 150,000원
# --------------------------------------------------------------------------------------------------
#
# 장안구 정자동
#
#
# 바른종합물류
# (  경력없으셔도 바로채용합니다. )	월급 : 5,000,000원
# --------------------------------------------------------------------------------------------------
#
# 수원시 장안구
#
#
# 희망공인중개사
# (  [9월 오픈멤버 신규채용] 주택홍보관 내근직- 월 700 )	월급 : 5,000,000원
# --------------------------------------------------------------------------------------------------
#
# 수원시 장안구
#
#
# #높은급여#최고복지#식사제공#가족같은분위
# (  [주급/초보가능/쾌적환경]편의점 물류센터 단순 피킹 )	월급 : 2,686,981원
# --------------------------------------------------------------------------------------------------
#
# 장안구 파장동
#
#
# 마트킹 북수원점/ ㈜참프레
# (  [5일단기알바/일8.6만]마트킹 북수원점 닭,오리 판촉 )	일급 : 86,140원
# --------------------------------------------------------------------------------------------------
#
# 수원시 장안구
#
#
# ㈜대명
# (  팩트쿠션 조립알바 // #일쉽고#동반가능#출근버스운행 )	시급 : 8,720원
# --------------------------------------------------------------------------------------------------
#
# 장안구 조원동
#
#
# ㈜CJ홈쇼핑 추가채용
# (  [월평균578만원] 비대면홈쇼핑배송 / 근무차량지원 )	월급 : 5,000,000원
# --------------------------------------------------------------------------------------------------
#
# 장안구 율전동
#
#
# 주식회사 한결글로벌로지스
# (  고액알바/당일지급/짧은근무/높은시급/택배하차분류/ )	시급 : 11,000원
# --------------------------------------------------------------------------------------------------
#
# 수원시 장안구
#
#
# 비비큐 수원파장행운점
# (  #초보가능 # 주중or주말 / 추후창업지원 /기업형복지 )	시급 : 9,000원
# --------------------------------------------------------------------------------------------------
#
# 수원시 장안구
#
#
# LGU+ 본사직영대리점(이오씨)
# (  월9회 휴무 기본급200만 평균급여 월350만원이상 경력 )	월급 : 3,500,000원
# --------------------------------------------------------------------------------------------------
#
# 장안구 조원동
#
#
# 성진자산관리㈜
# (  [건강관리협회 경기지부] 주차요원 알바 모집 )	시급 : 10,000원
# --------------------------------------------------------------------------------------------------
#
# 장안구 정자동
#
#
# 쿠팡풀필먼트서비스 유한회사
# (  [인천쿠팡17]오후조오픈/인센2만원/오전조3만원/단기 )	일급 : 91,500원
# --------------------------------------------------------------------------------------------------
#
# 장안구 조원동
#
#
# 쿠팡풀필먼트서비스 유한회사
# (  [인천쿠팡17]오후조오픈/인센2만원/오전조3만원/단기 )	일급 : 91,500원
# --------------------------------------------------------------------------------------------------
#
# 장안구 영화동
#
#
# 쿠팡풀필먼트서비스(유)
# (  [경기광주쿠팡]공휴수당포함 134,705원/9.20-22/오후 )	일급 : 134,705원
# --------------------------------------------------------------------------------------------------
#
# 수원시 장안구
#
#
# #동탄F팀# 69,760원-75,520원(누구나가능)2
# (  (오전조) 75,520원/단순업무/남여상관없이/바로/동반 )	일급 : 75,520원
# --------------------------------------------------------------------------------------------------
#
# 수원시 장안구
#
#
# 노트하우㈜ #대학생 #노트제작 #재택알바 #
# (  대학생 노트 제작 `단기 재택` 알바 구합니다 )	건별 : 300,000원
# --------------------------------------------------------------------------------------------------
#
# 수원시 장안구
#
#
# 다이소
# (  [직영사원/ 급여 GOOD] 다이소 용인물류 주&야간 남여 )	월급 : 3,000,000원
# --------------------------------------------------------------------------------------------------
#
# 장안구 율전동
#
#
# 쿠팡풀필먼트서비스(유)
# (  [이천3쿠팡]#단기알바#인센티브#익일지급#소화물#동반 )	일급 : 109,760원
# --------------------------------------------------------------------------------------------------
#
# 장안구 정자동
#
#
# 쿠팡풀필먼트서비스(유)
# (  [이천3쿠팡]#단기알바#인센티브#익일지급#소화물#동반 )	일급 : 109,760원
# --------------------------------------------------------------------------------------------------
